# %% [markdown]
# # list

# %%
lst = ["karthik",2,3.45,[5,6,7]]
lst
# Out:
# ['karthik', 2, 3.45, [5, 6, 7]]

# %%
lst.append("me")
lst
# Out:
# ['karthik', 2, 3.45, [5, 6, 7], 'me']

# %%
lst.clear()
lst
# Out:
# []

# %%
lst = ["karthik",2,3.45,[5,6,7]]
nst = lst.copy()
nst
# Out:
# ['karthik', 2, 3.45, [5, 6, 7]]

# %%
lst.count(2)
# Out:
# 1

# %%
lst.reverse()
lst
# Out:
# [[5, 6, 7], 3.45, 2, 'karthik']

# %% [markdown]
# # Dictionary

# %%
dic = {"name" : "karthik" , "age":"20" , "number":"12345"}
dic
# Out:
# {'name': 'karthik', 'age': '20', 'number': '12345'}

# %%
dic.get('name')
# Out:
# 'karthik'

# %%
dic["school"] = "KVR"
dic
# Out:
# {'name': 'karthik', 'age': '20', 'number': '12345', 'school': 'KVR'}

# %%
nic = dic.copy()
nic
# Out:
# {'name': 'karthik', 'age': '20', 'number': '12345', 'school': 'KVR'}

# %%
dic.popitem()
dic
# Out:
# {'name': 'karthik', 'age': '20', 'number': '12345'}

# %%
dic.pop("name")
dic
# Out:
# {'age': '20', 'number': '12345'}

# %%
d = {1 : "one" , 2 : "three"}
d1 = {2 : "two"}
d.update(d1)
d
# Out:
# {1: 'one', 2: 'two'}

# %% [markdown]
# # sets

# %%
st = {"karthik","me",1,2,2,4,6,2}
st
# Out:
# {1, 2, 4, 6, 'karthik', 'me'}

# %%
st.add("hi")
st
# Out:
# {1, 2, 4, 6, 'hi', 'karthik', 'me'}

# %%
ft = st.copy()
ft
# Out:
# {1, 2, 4, 6, 'hi', 'karthik', 'me'}

# %%
st.add(8)
st
# Out:
# {1, 2, 4, 6, 8, 'hi', 'karthik', 'me'}

# %%
st.issubset(ft)
# Out:
# False

# %%
d = {1,3,4,6,8,"mm"}
st.intersection(d)
# Out:
# {1, 4, 6, 8}

# %%
st.difference(d)
# Out:
# {2, 'hi', 'karthik', 'me'}

# %%
st.difference_update(d)
st
# Out:
# {2, 'hi', 'karthik', 'me'}

# %% [markdown]
# # tuple

# %%
tup = ("karthik","@","rajulapudi",2,3)
tup
# Out:
# ('karthik', '@', 'rajulapudi', 2, 3)

# %%
tup.count(2)
# Out:
# 1

# %%
tup.index('rajulapudi')
# Out:
# 2

# %% [markdown]
# # Boolean

# %%
ab = 1
dg = 2
ab < dg
# Out:
# True

# %% [markdown]
# # String

# %%
strg = "karthik"
strg
# Out:
# 'karthik'

# %%
strg.capitalize()
# Out:
# 'Karthik'

# %%
st1 = "RVL"
st1.casefold()
# Out:
# 'rvl'

# %%
srtn = "hello"
srtn1 = srtn.center(20,'#')
print(srtn1)
# Out:
# #######hello########

# %%
srtn.find("l")
# Out:
# 2

# %%
dtr = "{} is two"
print(dtr.format("2"))
# Out:
# 2 is two
